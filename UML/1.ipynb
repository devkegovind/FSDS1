# %%
'''import os
import openpyxl
import pandas as pd

directory = [r"D:\\Downloads\\data[1]\\Training_Batch_Files", r"D:\\Downloads\data[1]\\Training_Batch_Files\\wafer_29012020_060756.csv"]
df1 = pd.DataFrame()

for file in os.listdir(directory):
    if file.endswith('.csv'):
        file_path = os.path.join(directory, file)
        df = pd.read_csv(file_path)
        df1 = pd.concat([df1, df])
'''
# Out:
# 'import os\nimport openpyxl\nimport pandas as pd\n\ndirectory = [r"D:\\Downloads\\data[1]\\Training_Batch_Files", r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_29012020_060756.csv"]\ndf1 = pd.DataFrame()\n\nfor file in os.listdir(directory):\n    if file.endswith(\'.csv\'):\n        file_path = os.path.join(directory, file)\n        df = pd.read_csv(file_path)\n        df1 = pd.concat([df1, df])\n'

# %%
import pandas as pd
import numpy as np

# %%
'''
df11 = pd.read_csv(r"D:\\Downloads\\data[1]\Training_Batch_Files\\wafer_29012020_050617.csv")
df2 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_29012020_060756.csv")
df3 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_31012020_090811.csv")
df4 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_fault_detection.csv")
df5 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_text_130532.csv")
df6 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer12_20012.csv")
df7 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Waferdefault_15010_130532.csv")
df8 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_15010_130532.csv")
df9 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_07012020_223345.csv")
df10 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_08012020_120000.csv")
df11 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_10012020_131534.csv")
df12 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_11012020_151432.csv")
df13 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_12012020_111.csv")
df14 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_12012020_111213.csv")
df15 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_13012020_090817.csv")
df16 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_13012020_141000.csv")
df17 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_13012020_090817.csv")
df18 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_13012020_141000.csv")
df19 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_14012020_113045.csv")
df20 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_15012020_130532.csv")
df21 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_16012020_051629.csv")
df22 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_16012020_051629.csv")
df23 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_17012020_125434.csv")
df24 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_18012020_121532.csv")
df25 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_19012020_141432.csv")
df26 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_20012020_090819.csv")
df27 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_20012020_135132.csv")
df28 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_20022020_090716.csv")
df29 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_21012020_080913.csv")
df30 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_21012020_143634.csv")
df31 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_22012020_173245.csv")
df32 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_22022020_041119.csv")
df33 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_23012020_011008.csv")
df34 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_23012020_041211.csv")
df35 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_23012020_163456.csv")
df36 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_24012020_150121.csv")
df37 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_25012020_142112.csv")
df38 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_27012020_080911.csv")
df39 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_28012020_051011.csv")
df40 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_28012020_090817.csv")
df41 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_28042020_031911.csv")
df42 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_07012020_000000.csv")
df43 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_07012020_041011.csv")
'''
# Out:
# '\ndf11 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_29012020_050617.csv")\ndf2 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_29012020_060756.csv")\ndf3 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\wafer_31012020_090811.csv")\ndf4 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_fault_detection.csv")\ndf5 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_text_130532.csv")\ndf6 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer12_20012.csv")\ndf7 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Waferdefault_15010_130532.csv")\ndf8 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_15010_130532.csv")\ndf9 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_07012020_223345.csv")\ndf10 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_Batch_Files\\Wafer_08012020_120000.csv")\ndf11 = pd.read_csv(r"D:\\Downloads\\data[1]\\Training_
# ...

# %%
#df11.head()

# %%
#df1 = pd.concat([df11, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40, df41, df42, df43], axis = 'rows', ignore_index=True)

# %%
import os
import openpyxl
import pandas as pd

directory = r"D:\\Downloads\\data[1]\\Training_Batch_Files"
df1 = pd.DataFrame()

for file in os.listdir(directory):
    if file.endswith('.csv'):
        file_path = os.path.join(directory, file)
        df = pd.read_csv(file_path)
        df1 = pd.concat([df1, df])

df1.to_excel('Final1.xlsx', index=True)

# %%
df1.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0  Wafer-1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1  Wafer-1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2  Wafer-1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3  Wafer-1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4  Wafer-1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Unnamed: 581  Unnamed: 582
# 0  107.3989    0.1229    1.5447  ...           NaN           NaN  \
# 1  111.7644    0.1241    1.4855  ...           NaN           NaN
# 2  111.7644    0.1241    1.4089  ...           NaN           NaN
# 3  100.4111    0.1238    1.6217  ...           NaN           NaN
# 4  100.9744    0.1244    1.4413  ...           NaN           NaN
#
#    Unnamed: 583  Unnamed: 584  Unnamed: 585  Unnamed: 586  Unnamed: 587
# ...

# %%
df1 = df1.drop('Good/Bad', axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3980 entries, 0 to 100
# Columns: 628 entries, Unnamed: 0 to Unnamed: 590
# dtypes: float64(624), object(4)
# memory usage: 19.1+ MB

# %%
df1.describe(include='all').T
# Out:
#                count unique        top freq         mean         std      min
# Unnamed: 0      3980   1537  Wafer-800    8          NaN         NaN      NaN  \
# Sensor-1      3963.0    NaN        NaN  NaN  3013.811812   73.149044  2743.24
# Sensor-2      3960.0    NaN        NaN  NaN  2495.254755   81.310429  2158.75
# Sensor-3      3942.0    NaN        NaN  NaN  2199.344513   29.521253  2060.66
# Sensor-4      3942.0    NaN        NaN  NaN  1380.313126  433.285353      0.0
# ...              ...    ...        ...  ...          ...         ...      ...
# Unnamed: 586     0.0    NaN        NaN  NaN          NaN         NaN      NaN
# Unnamed: 587     0.0    NaN        NaN  NaN          NaN         NaN      NaN
# Unnamed: 588     0.0    NaN        NaN  NaN          NaN         NaN      NaN
# Unnamed: 589     0.0    NaN        NaN  NaN          NaN         NaN      NaN
# Unnamed: 590     0.0    NaN        NaN  NaN          NaN         NaN      NaN
#
# ...

# %%
df1.iloc[:,591:]
# Out:
#      Unnamed: 554  Unnamed: 555  Unnamed: 556  Unnamed: 557  Unnamed: 558
# 0             NaN           NaN           NaN           NaN           NaN  \
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 96            NaN           NaN           NaN           NaN           NaN
# 97            NaN           NaN           NaN           NaN           NaN
# 98            NaN           NaN           NaN           NaN           NaN
# 99            NaN           NaN           NaN           NaN           NaN
# 100           NaN           NaN           NaN           NaN           NaN
#
#      Unnamed: 559  Unnamed: 560  Unnamed: 561  Unnamed: 562  Unnamed: 563
# ...

# %%
columns = df1.columns.to_list()
print(columns)
# Out:
# ['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4', 'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9', 'Sensor-10', 'Sensor-11', 'Sensor-12', 'Sensor-13', 'Sensor-14', 'Sensor-15', 'Sensor-16', 'Sensor-17', 'Sensor-18', 'Sensor-19', 'Sensor-20', 'Sensor-21', 'Sensor-22', 'Sensor-23', 'Sensor-24', 'Sensor-25', 'Sensor-26', 'Sensor-27', 'Sensor-28', 'Sensor-29', 'Sensor-30', 'Sensor-31', 'Sensor-32', 'Sensor-33', 'Sensor-34', 'Sensor-35', 'Sensor-36', 'Sensor-37', 'Sensor-38', 'Sensor-39', 'Sensor-40', 'Sensor-41', 'Sensor-42', 'Sensor-43', 'Sensor-44', 'Sensor-45', 'Sensor-46', 'Sensor-47', 'Sensor-48', 'Sensor-49', 'Sensor-50', 'Sensor-51', 'Sensor-52', 'Sensor-53', 'Sensor-54', 'Sensor-55', 'Sensor-56', 'Sensor-57', 'Sensor-58', 'Sensor-59', 'Sensor-60', 'Sensor-61', 'Sensor-62', 'Sensor-63', 'Sensor-64', 'Sensor-65', 'Sensor-66', 'Sensor-67', 'Sensor-68', 'Sensor-69', 'Sensor-70', 'Sensor-71', 'Sensor-72', 'Sensor-73', 'Sensor-74', 'Sensor-75', 'Sensor-76', 'Sen
# ...

# %%
df1 = df1.drop(['Unnamed: 554', 'Unnamed: 555', 'Unnamed: 556', 'Unnamed: 557', 'Unnamed: 558', 'Unnamed: 559', 'Unnamed: 560', 'Unnamed: 561', 'Unnamed: 562', 'Unnamed: 563', 'Unnamed: 564', 'Unnamed: 565', 'Unnamed: 566', 'Unnamed: 567', 'Unnamed: 568', 'Unnamed: 569', 'Unnamed: 570', 'Unnamed: 571', 'Unnamed: 572', 'Unnamed: 573', 'Unnamed: 574', 'Unnamed: 575', 'Unnamed: 576', 'Unnamed: 577', 'Unnamed: 578', 'Unnamed: 579', 'Unnamed: 580', 'Unnamed: 581', 'Unnamed: 582', 'Unnamed: 583', 'Unnamed: 584', 'Unnamed: 585', 'Unnamed: 586', 'Unnamed: 587', 'Unnamed: 588', 'Unnamed: 589', 'Unnamed: 590'], axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3980 entries, 0 to 100
# Columns: 591 entries, Unnamed: 0 to Sensor-590
# dtypes: float64(587), object(4)
# memory usage: 18.0+ MB

# %%
df1['Unnamed: 0']= df1['Unnamed: 0'].str.split('-').str[1]

# %%
categorical_columns = df1.columns[df1.dtypes == 'object']

# %%
categorical_columns
# Out:
# Index(['Unnamed: 0', 'Sensor-332', 'Sensor-576', 'Sensor-586'], dtype='object')

# %%
df1.shape
# Out:
# (3980, 591)

# %%
df1['Unnamed: 0'] = df1['Unnamed: 0'].astype('int')

# %%
df1['Sensor-332'].fillna(df1['Sensor-332'].mode()[0], inplace = True)

# %%
df1['Sensor-332'].isna().sum()
# Out:
# 0

# %%
text_mask = pd.isna(df1['Sensor-332']) |df1['Sensor-332'].str.match(r'^[A-Za-z0-1 ]+$')
text_data = df1.loc[text_mask, 'Sensor-332']

date_data = pd.to_datetime(df1.loc[~text_mask, 'Sensor-332'], dayfirst=True)

# %%
df1['Sensor-332'] = pd.DataFrame(date_data)

# %%
df1['Sensor-332'] = df1['Sensor-332'].astype('int64')

# %%
df1
# Out:
#      Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0          1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1          1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2          1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3          1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4          1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
# ..          ...       ...       ...        ...        ...       ...       ...
# 96          595   2989.44   2487.66  2201.0667   880.2317    1.4148     100.0
# 97          596   2996.89   2492.40  2217.8667  1275.0917    1.5487     100.0
# 98          597   2990.85   2485.99  2167.9444   861.8041    1.4140     100.0
# 99          598   3059.43   2473.55  2214.9333  1663.7024    1.0203     100.0
# 100         599   3024.54   2420.25  2167.9444   861.8041    1.4140     100.0
#
# ...

# %%
df1.columns[df1.dtypes=='object']
# Out:
# Index(['Sensor-576', 'Sensor-586'], dtype='object')

# %%
df1['Sensor-576']  = df1['Sensor-576'].replace('invalid', np.nan)

# %%
df1['Sensor-576'].unique()
# Out:
# array([0.0849, 0.056 , 0.1495, 0.1086, 0.0758, 0.0828, 0.0751, 0.0736,
#        0.1255, 0.1016, 0.105 , 0.0898, 0.0358, 0.1336, 0.0728, 0.3247,
#        0.1355, 0.0793, 0.1018, 0.0775, 0.0613, 0.0378, 0.1441, 0.1331,
#        0.1213, 0.054 , 0.0927, 0.076 , 0.1286, 0.2947, 0.1483, 0.104 ,
#        0.0674, 0.1198, 0.0906, 0.0562, 0.1146, 0.1526, 0.0822, 0.1105,
#        0.1061, 0.1285, 0.1056, 0.0724, 0.08  , 0.053 , 0.1169, 0.0937,
#        0.0753, 0.286 , 0.1222, 0.1346, 0.0953, 0.0584, 0.0738, 0.3337,
#        0.087 , 0.0925, 0.0963, 0.0858, 0.1111, 0.0985, 0.0726, 0.0966,
#        0.0923, 0.0782, 0.0745, 0.0757, 0.2255, 0.0883, 0.099 , 0.1102,
#        0.3883, 0.0429, 0.1038, 0.1153, 0.0994, 0.0855, 0.0771, 0.071 ,
#        0.0777, 0.0905, 0.0868, 0.0415, 0.0705, 0.1197, 0.0663, 0.1065,
#        0.0854, 0.0939, 0.0617, 0.0819, 0.0833, 0.0928, 0.0892, 0.1139,
#        0.066 , 0.1052, 0.0772, 0.1565, 0.0861, 0.0862, 0.0827, 0.0557,
# ...

# %%
df1.dropna(subset='Sensor-576', inplace = True)

# %%
df1['Sensor-576'].dtypes
# Out:
# dtype('float64')

# %%
df1['Sensor-586'].isna().sum()
# Out:
# 2

# %%
df1['Sensor-586'] = df1['Sensor-586'].fillna(df1['Sensor-586'].mode()[0])

# %%
df1['Sensor-586'].unique()
# Out:
# array([2.7317, 3.2353, 3.1508, ..., 2.7314, 2.9604, 3.8875])

# %%
df1['Sensor-586'].isna().sum()
# Out:
# 0

# %%
df1['Sensor-586'] = df1['Sensor-586'].astype('float64')

# %%
df1['Sensor-586'].dtypes
# Out:
# dtype('float64')

# %%
categorical_columns = df1.columns[df1.dtypes == 'object']

# %%
categorical_columns
# Out:
# Index([], dtype='object')

# %%
df1.isna().sum()
# Out:
# Unnamed: 0     0
# Sensor-1      16
# Sensor-2      20
# Sensor-3      35
# Sensor-4      35
#               ..
# Sensor-586     0
# Sensor-587     0
# Sensor-588     0
# Sensor-589     0
# Sensor-590     0
# Length: 591, dtype: int64

# %%
num_columns = df1.columns[df1.dtypes != 'object']

# %%
num_columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-581', 'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585',
#        'Sensor-586', 'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590'],
#       dtype='object', length=591)

# %%
df1['Sensor-1'].median()
# Out:
# 3010.1000000000004

# %%
for col in df1[num_columns].columns:
    df1[col].fillna(df1[col].median(), inplace=True)

# %%
df1.isna().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      0
# Sensor-2      0
# Sensor-3      0
# Sensor-4      0
#              ..
# Sensor-586    0
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Length: 591, dtype: int64

# %%
df1.isna().sum().sum()
# Out:
# 0

# %%
df1.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0        1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1        1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2        1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3        1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4        1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-581  Sensor-582  Sensor-583
# 0  107.3989    0.1229    1.5447  ...      0.0055    368.8936      0.5008  \
# 1  111.7644    0.1241    1.4855  ...      0.0047     70.5588      0.5018
# 2  111.7644    0.1241    1.4089  ...      0.0053    197.1279      0.5026
# 3  100.4111    0.1238    1.6217  ...      0.0059    120.6365      0.5011
# 4  100.9744    0.1244    1.4413  ...      0.0047     70.5588      0.4986
#
# ...

# %%
df2 = df1.copy()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
kmeans = KMeans()

# %%
kmeans.fit(df1)
# Out:
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans()

# %%
df1['Labels'] = pd.DataFrame(kmeans.labels_)
# Out:
# C:\Users\Neeta Devke\AppData\Local\Temp\ipykernel_9856\2454954123.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df1['Labels'] = pd.DataFrame(kmeans.labels_)

# %%
kmeans.cluster_centers_
# Out:
# array([[8.47741071e+02, 3.02129366e+03, 2.48793563e+03, ...,
#         1.66758929e-02, 5.30535714e-03, 8.99846321e+01],
#        [7.28830446e+02, 3.01056443e+03, 2.49647564e+03, ...,
#         1.64755906e-02, 5.28262467e-03, 9.89448925e+01],
#        [6.64110912e+02, 3.01223639e+03, 2.49458025e+03, ...,
#         1.60921288e-02, 5.16976744e-03, 9.73572996e+01],
#        ...,
#        [7.30192308e+02, 3.01013413e+03, 2.51706457e+03, ...,
#         1.66826923e-02, 5.14182692e-03, 9.70372827e+01],
#        [8.55461176e+02, 3.01544520e+03, 2.49671372e+03, ...,
#         1.69621176e-02, 5.51717647e-03, 9.38769915e+01],
#        [9.37490909e+02, 3.03158136e+03, 2.50387082e+03, ...,
#         1.57418182e-02, 5.00454545e-03, 1.03932723e+02]])

# %%
df1.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0        1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1        1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2        1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3        1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4        1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584
# 0  107.3989    0.1229    1.5447  ...    368.8936      0.5008      0.0137  \
# 1  111.7644    0.1241    1.4855  ...     70.5588      0.5018      0.0162
# 2  111.7644    0.1241    1.4089  ...    197.1279      0.5026      0.0158
# 3  100.4111    0.1238    1.6217  ...    120.6365      0.5011      0.0125
# 4  100.9744    0.1244    1.4413  ...     70.5588      0.4986      0.0120
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Labels'],
#       dtype='object', length=592)

# %%
X = df1.drop('Labels', axis = 1)
y = df1['Labels']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# %%
X_train
# Out:
#     Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 15         615   3072.21   2610.62  2214.9333  1663.7024    1.0203     100.0  \
# 29        1229   3133.75   2673.38  2173.2778  1116.2950    0.8525     100.0
# 5          504   2997.28   2357.99  2141.0667  1236.5212    0.9698     100.0
# 6          505   3025.10   2475.18  2235.0556  1302.6607    1.6347     100.0
# 85        1486   3012.34   2416.09  2192.7889  1268.5852    1.9935     100.0
# ..         ...       ...       ...        ...        ...       ...       ...
# 29         329   2942.16   2450.05  2224.0000  1510.0797    1.5611     100.0
# 93         493   2960.22   2502.25  2183.3111  1588.5090    1.6269     100.0
# 59         259   2962.65   2535.19  2214.7111  1493.8781    1.5899     100.0
# 29         330   3012.18   2590.80  2197.6778  1056.7817    1.3168     100.0
# 96        1197   2957.77   2555.41  2199.6556  1140.3983    1.3369     100.0
#
# ...

# %%
WCSS = []

for k in range(2, 11):
    kmean = KMeans(n_clusters=k, init="k-means++")
    kmean.fit(X_train)
    WCSS.append(kmean.inertia_)
# Out:
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
WCSS
# Out:
# [119599966005.68394,
#  88454987337.95576,
#  75093478339.5458,
#  67599235330.76495,
#  61416259035.866295,
#  55835691935.63156,
#  51437137770.97663,
#  47848621459.69434,
#  45266613997.28261]

# %%
plt.plot(range(2,11), WCSS)
plt.xticks()
plt.xlabel("Number Of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans1 = KMeans(n_clusters=4, init="k-means++")

# %%
kmeans1.fit(df2)
# Out:
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
df2['Labels'] = pd.DataFrame(kmeans1.labels_)

# %%
df2.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0        1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1        1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2        1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3        1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4        1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584
# 0  107.3989    0.1229    1.5447  ...    368.8936      0.5008      0.0137  \
# 1  111.7644    0.1241    1.4855  ...     70.5588      0.5018      0.0162
# 2  111.7644    0.1241    1.4089  ...    197.1279      0.5026      0.0158
# 3  100.4111    0.1238    1.6217  ...    120.6365      0.5011      0.0125
# 4  100.9744    0.1244    1.4413  ...     70.5588      0.4986      0.0120
#
# ...

# %%
df2.isna().sum().sum()
# Out:
# 0

# %%
df2['Labels'].isna().sum()
# Out:
# 0

# %%
kmeans1.cluster_centers_
# Out:
# array([[8.83025974e+02, 3.01905503e+03, 2.48937846e+03, ...,
#         1.72141002e-02, 5.62615955e-03, 9.94062310e+01],
#        [8.83118812e+02, 3.02302020e+03, 2.49410814e+03, ...,
#         1.59712871e-02, 5.12475248e-03, 8.91303928e+01],
#        [7.01812227e+02, 3.01103945e+03, 2.50580856e+03, ...,
#         1.65408297e-02, 5.19039301e-03, 9.05135288e+01],
#        [7.26984027e+02, 3.01134763e+03, 2.49610201e+03, ...,
#         1.63858764e-02, 5.25809164e-03, 9.85875039e+01]])

# %%
y_labels = kmeans1.predict(X_train)

# %%
y_labels
# Out:
# array([2, 1, 3, ..., 3, 2, 1])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a Pandas DataFrame 'df' with columns 'column1' and 'column2' containing the data for the scatter plot

# Create a scatter plot using the values from 'column1' as x-axis and 'column2' as y-axis
plt.scatter(df1['Sensor-1'], df1['Sensor-2'])

# Add labels and title to the plot
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')

# Display the plot
plt.show()

# %%
WCSS1 = []

for k in range(2, 11):
    kmeans1 = KMeans(n_clusters=k, init="k-means++")
    kmeans1.fit(X_train)
    WCSS1.append(kmeans1.inertia_)
# Out:
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# d:\FSDS\venv\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from kneed import KneeLocator

# %%
k = KneeLocator(range(2,11), WCSS1, curve = 'convex', direction='decreasing')

# %%
k.elbow
# Out:
# 4

# %%
df2
# Out:
#      Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0          1400   3034.74   2458.90  2192.1889  1435.9611    2.3870     100.0  \
# 1          1401   3038.57   2380.39  2205.5000  1287.3538    2.3842     100.0
# 2          1402   2902.88   2259.49  2205.5000  1287.3538    2.3842     100.0
# 3          1403   3001.45   2481.72  2162.5556  1041.0369    1.4305     100.0
# 4          1404   2975.72   2585.72  2150.0556  1215.2183    1.4756     100.0
# ..          ...       ...       ...        ...        ...       ...       ...
# 96          595   2989.44   2487.66  2201.0667   880.2317    1.4148     100.0
# 97          596   2996.89   2492.40  2217.8667  1275.0917    1.5487     100.0
# 98          597   2990.85   2485.99  2167.9444   861.8041    1.4140     100.0
# 99          598   3059.43   2473.55  2214.9333  1663.7024    1.0203     100.0
# 100         599   3024.54   2420.25  2167.9444   861.8041    1.4140     100.0
#
# ...

# %%
df2.to_excel('Final.xlsx')

# %% [markdown]
# <h1 style="text-align:center"><b>EXAPLORATORY DATA ANALYSIS</b></h1>

# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT DATASET**

# %%
df = pd.read_excel(r'D:\\FSDS\UML\\Final.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4
# 0             0        1400   3034.74   2458.90  2192.1889  1435.9611  \
# 1             1        1401   3038.57   2380.39  2205.5000  1287.3538
# 2             2        1402   2902.88   2259.49  2205.5000  1287.3538
# 3             3        1403   3001.45   2481.72  2162.5556  1041.0369
# 4             4        1404   2975.72   2585.72  2150.0556  1215.2183
#
#    Sensor-5  Sensor-6  Sensor-7  Sensor-8  ...  Sensor-582  Sensor-583
# 0    2.3870       100  107.3989    0.1229  ...    368.8936      0.5008  \
# 1    2.3842       100  111.7644    0.1241  ...     70.5588      0.5018
# 2    2.3842       100  111.7644    0.1241  ...    197.1279      0.5026
# 3    1.4305       100  100.4111    0.1238  ...    120.6365      0.5011
# 4    1.4756       100  100.9744    0.1244  ...     70.5588      0.4986
#
#    Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589
# ...

# %%
df.shape
# Out:
# (3780, 593)

# %%
df.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4
# 3775            96         595   2989.44   2487.66  2201.0667   880.2317  \
# 3776            97         596   2996.89   2492.40  2217.8667  1275.0917
# 3777            98         597   2990.85   2485.99  2167.9444   861.8041
# 3778            99         598   3059.43   2473.55  2214.9333  1663.7024
# 3779           100         599   3024.54   2420.25  2167.9444   861.8041
#
#       Sensor-5  Sensor-6  Sensor-7  Sensor-8  ...  Sensor-582  Sensor-583
# 3775    1.4148       100  106.5478    0.1211  ...     70.5588      0.4933  \
# 3776    1.5487       100  105.2933    0.1230  ...     70.5588      0.5071
# 3777    1.4140       100  106.6033    0.1243  ...     70.5588      0.5015
# 3778    1.0203       100  100.4456    0.1247  ...    108.6076      0.4973
# 3779    1.4140       100  106.6033    0.1243  ...     70.5588      0.5006
#
#       Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589
# ...

# %%
df.sample(5)
# Out:
#       Unnamed: 0.1  Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4
# 788             87         187   2940.50   2441.61  2205.2889  1630.3112  \
# 2703            25         826   3048.39   2489.15  2205.7445  1363.1048
# 1120            19         319   2990.95   2379.96  2218.5778  1632.2734
# 673             72        1072   3099.37   2450.29  2178.5889  1135.3544
# 3335            57        1358   2994.64   2484.71  2200.2111  1048.3108
#
#       Sensor-5  Sensor-6  Sensor-7  Sensor-8  ...  Sensor-582  Sensor-583
# 788     1.2733       100   98.8056    0.1218  ...     61.6014      0.4981  \
# 2703    1.0518       100  101.8644    0.1220  ...     70.5588      0.4956
# 1120    0.8396       100   98.1311    0.1211  ...     70.5588      0.4933
# 673     0.8614       100  103.7022    0.1205  ...     70.5588      0.5015
# 3335    1.6485       100   98.3222    0.1214  ...     70.5588      0.5008
#
#       Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3780 entries, 0 to 3779
# Columns: 593 entries, Unnamed: 0.1 to Labels
# dtypes: float64(468), int64(125)
# memory usage: 17.1 MB

# %%
df.describe(include='all').T
# Out:
#                count         mean         std        min        25%
# Unnamed: 0.1  3780.0    48.947090   28.993614     0.0000    24.0000  \
# Unnamed: 0    3780.0   762.871958  436.909145     1.0000   423.0000
# Sensor-1      3780.0  3013.656849   73.069984  2743.2400  2967.5400
# Sensor-2      3780.0  2496.106267   80.994866  2158.7500  2453.4700
# Sensor-3      3780.0  2199.236473   29.660417  2060.6600  2179.1111
# ...              ...          ...         ...        ...        ...
# Sensor-587    3780.0     0.021396    0.012115    -0.0169     0.0139
# Sensor-588    3780.0     0.016478    0.008451     0.0032     0.0108
# Sensor-589    3780.0     0.005288    0.002777     0.0010     0.0034
# Sensor-590    3780.0    96.715213   92.410154     0.0000    44.1220
# Labels        3780.0     2.215344    1.167468     0.0000     1.0000
#
#                     50%        75%        max
# Unnamed: 0.1    49.0000    74.0000   100.0000
# Unnamed: 0     695.5000  1165.0000  1537.0000
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Sensor-1        0
# Sensor-2        0
# Sensor-3        0
#                ..
# Sensor-587      0
# Sensor-588      0
# Sensor-589      0
# Sensor-590      0
# Labels          0
# Length: 593, dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# **DROP UNWANTED COLUMN FROM DATASET**

# %%
df.drop('Unnamed: 0.1', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0        1400   3034.74   2458.90  2192.1889  1435.9611    2.3870       100  \
# 1        1401   3038.57   2380.39  2205.5000  1287.3538    2.3842       100
# 2        1402   2902.88   2259.49  2205.5000  1287.3538    2.3842       100
# 3        1403   3001.45   2481.72  2162.5556  1041.0369    1.4305       100
# 4        1404   2975.72   2585.72  2150.0556  1215.2183    1.4756       100
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584
# 0  107.3989    0.1229    1.5447  ...    368.8936      0.5008      0.0137  \
# 1  111.7644    0.1241    1.4855  ...     70.5588      0.5018      0.0162
# 2  111.7644    0.1241    1.4089  ...    197.1279      0.5026      0.0158
# 3  100.4111    0.1238    1.6217  ...    120.6365      0.5011      0.0125
# 4  100.9744    0.1244    1.4413  ...     70.5588      0.4986      0.0120
#
# ...

# %%
df['Sensor-1'][].plot(kind='bar')
# Out:
# <Axes: >
